# %%
using Pkg
Pkg.activate(".")

# %%
using Revise
using DeconvOptim, TestImages, ImageShow, Plots, LinearAlgebra, IndexFunArrays, Noise
using FourierTools, SpecialFunctions, FFTW, Images, Tullio, PGFPlotsX
using Statistics, StatsBase
# Out:
# ┌ Info: Precompiling PGFPlotsX [8314cec4-20b6-5062-9cdb-752b83310925]
# └ @ Base loading.jl:1317
# ┌ Info: Precompiling Contour [d38c429a-6771-53c6-b99e-75d170b6e991]
# └ @ Base loading.jl:1317

# %%
img = Float32.(testimage("resolution_test_512"));

# %%
radius = 51.2
f_max = 51.2 / size(img, 1) * 2
psf = Float32.(DeconvOptim.generate_psf(size(img), radius));

# %%
img_n = Float32.(poisson(DeconvOptim.conv(img, psf), 100));

# %%
reg = DeconvOptim.GR(ϵ=1f-8)
#reg = TV();

# %%
iter=50

λ = 0.03

ncc_log_no_reg = Float32[]
ncc_log_reg = Float32[]
ncc_log_reg_strong = Float32[]

debug_no_reg(rec) = push!(ncc_log_no_reg, DeconvOptim.normalized_cross_correlation(img, rec))
debug_reg(rec) = push!(ncc_log_reg, DeconvOptim.normalized_cross_correlation(img, rec))
debug_reg_strong(rec) = push!(ncc_log_reg_strong, DeconvOptim.normalized_cross_correlation(img, rec))

img_deconv_reg, r = deconvolution(img_n, psf, regularizer=reg, iterations=iter, λ=λ, debug_f=debug_reg);
@show r
img_deconv_reg_strong, r = deconvolution(img_n, psf, regularizer=reg, iterations=iter, λ=0.5,  debug_f=debug_reg_strong);
@show r
img_deconv_nothing, r = deconvolution(img_n, psf, regularizer=nothing, iterations=iter, λ=λ,  debug_f=debug_no_reg);
@show r

img_deconv_reg_opt, r = deconvolution(img_n, psf, regularizer=reg, iterations=21, λ=λ);

img_deconv_nothing_opt, r = deconvolution(img_n, psf, regularizer=nothing, iterations=10, λ=λ);

0;

# remove duplicates to get the values after each iterations
filter_dup(x) = rle(x)[1]
#ncc_log_no_reg = filter_dup(ncc_log_no_reg)
#ncc_log_reg = filter_dup(ncc_log_reg)
#ncc_log_reg_strong = filter_dup(ncc_log_reg_strong)
# Out:
# r =  * Status: success
#
#  * Candidate solution
#     Final objective value:     -3.707648e+04
#
#  * Found with
#     Algorithm:     L-BFGS
#
#  * Convergence measures
#     |x - x'|               = 7.45e-09 ≰ 0.0e+00
#     |x - x'|/|x'|          = 1.89e-09 ≰ 0.0e+00
#     |f(x) - f(x')|         = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 0.00e+00 ≤ 0.0e+00
#     |g(x)|                 = 5.60e-03 ≰ 1.0e-08
#
#  * Work counters
#     Seconds run:   2  (vs limit Inf)
#     Iterations:    24
#     f(x) calls:    51
#     ∇f(x) calls:   25
#
# r =  * Status: success
#
#  * Candidate solution
#     Final objective value:     -3.179400e+04
#
#  * Found with
#     Algorithm:     L-BFGS
#
#  * Convergence measures
#     |x - x'|               = 1.54e-08 ≰ 0.0e+00
#     |x - x'|/|x'|          = 4.17e-09 ≰ 0.0e+00
#     |f(x) - f(x')|         = 0.00e+00 ≤ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 0.00e+00 ≤ 0.0e+00
#     |g(x)|                 = 2.24e-02 ≰ 1.0e-08
#
#  * Work counters
#     Seconds run:   2  (vs limit Inf)
#     Iterations:    36
#     f(x) calls:    85
#     ∇f(x) calls:   37
#
# r =  * Status: failure (reached maximum number of iterations)
#
#  * Candidate solution
#     Final objective value:     -3.815265e+04
#
#  * Found with
#     Algorithm:     L-BFGS
#
#  * Convergence measures
#     |x - x'|               = 6.81e-02 ≰ 0.0e+00
#     |x - x'|/|x'|          = 9.77e-03 ≰ 0.0e+00
#     |f(x) - f(x')|         = 1.09e+00 ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 2.85e-05 ≰ 0.0e+00
#     |g(x)|                 = 1.32e-01 ≰ 1.0e-08
#
#  * Work counters
#     Seconds run:   1  (vs limit Inf)
#     Iterations:    50
#     f(x) calls:    57
#     ∇f(x) calls:   51
# filter_dup (generic function with 1 method)

# %%
plot(ncc_log_no_reg, label="no reg", ylim=(0.8, 0.95))
plot!(ncc_log_reg, label="regularizer")
plot!(ncc_log_reg_strong, label="strong")

# %%
#save("../../paper/figures/fabio_blurry.png", img_blurry ./ maximum(img_blurry))
#save("../../paper/figures/fabio_deconv_regularizer_005_iter_30.png", min.(1.0, img_deconv_reg))
#save("../../paper/figures/fabio_deconv_no_reg_iter_30.png", img_deconv_nothing ./ maximum(img_deconv_nothing))

save("../../paper/figures/resolution_test_chart_blurry.png", min.(1, img_n))
save("../../paper/figures/resolution_test_chart_regularizer_008_iter_21.png", min.(1.0, img_deconv_reg))
save("../../paper/figures/resolution_test_chart_no_reg_iter_50.png", min.(1.0, img_deconv_nothing))
save("../../paper/figures/resolution_test_chart_no_reg_iter_10.png", min.(1.0, img_deconv_nothing_opt))
# Out:
# 0

# %%
[Gray.(img_n) Gray.(img_deconv_reg) Gray.(img_deconv_nothing) Gray.(img_deconv_reg_strong)]
# Out:
# 512×2048 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.0)         …  Gray{Float32}(2.35951f-7)
#  Gray{Float32}(0.0)            Gray{Float32}(2.81396f-7)
#  Gray{Float32}(0.0)            Gray{Float32}(2.15628f-6)
#  Gray{Float32}(0.0)            Gray{Float32}(1.17525f-5)
#  Gray{Float32}(0.0)            Gray{Float32}(7.72929f-5)
#  Gray{Float32}(0.0)         …  Gray{Float32}(0.000554992)
#  Gray{Float32}(0.0)            Gray{Float32}(0.00276918)
#  Gray{Float32}(0.0)            Gray{Float32}(0.00656596)
#  Gray{Float32}(0.0)            Gray{Float32}(0.0076622)
#  Gray{Float32}(0.0)            Gray{Float32}(0.00695586)
#  Gray{Float32}(0.0)         …  Gray{Float32}(0.00718106)
#  Gray{Float32}(0.0)            Gray{Float32}(0.00869668)
#  Gray{Float32}(0.0)            Gray{Float32}(0.00965123)
#  ⋮                          ⋱
#  Gray{Float32}(0.0)         …  Gray{Float32}(0.000447251)
#  Gray{Float32}(0.0)            Gray{Float32}(0.000767011)
#  Gray{Float32}(0.0)            Gray{Float32}(0.00163527)
#  Gray{Float32}(0.0)            Gray{Float32}(0.00353057)
#  Gray{Float32}(0.0)            Gray{Float32}(0.00694211)
#  Gray{Float32}(0.0)         …  Gray{Float32}(0.0115216)
#  Gray{Float32}(0.0)            Gray{Float32}(0.0152411)
#  Gray{Float32}(0.00920674)     Gray{Float32}(0.0164411)
#  Gray{Float32}(0.0)            Gray{Float32}(0.0168157)
#  Gray{Float32}(0.0)            Gray{Float32}(0.0201934)
#  Gray{Float32}(0.0)         …  Gray{Float32}(0.0326102)
#  Gray{Float32}(0.0)            Gray{Float32}(1.40048f-9)

# %%
f, G_R_reg = DeconvOptim.relative_energy_regain(img, img_deconv_reg_opt)
f, G_R_reg_strong = DeconvOptim.relative_energy_regain(img, img_deconv_reg_strong)
f, G_R_nothing = DeconvOptim.relative_energy_regain(img, img_deconv_nothing_opt)
f, G_R_n = DeconvOptim.relative_energy_regain(img, img_n);

f_rel = f ./ f_max;

# %%
plt1 = @pgf PGFPlotsX.Axis(
    {xlabel="\$f/f_{\\textrm{max}} \$", ylabel="relative energy regain \$G_{\\textrm{R}}\$",
        xmin=0, xmax=2.5, ymin=-1, ymax=1.2, 
        legend_pos="north east", legend_entries={"measured", "GR \$\\lambda=0.08\$",  "GR \$\\lambda=0.5\$", "no regularizer"}},
    
    Plot({"sharp plot", color="red"
        },
        Table([f_rel, G_R_n])
    ),
    Plot({"sharp plot", color="blue"
        },
        Table([f_rel,  G_R_reg])
    ),
    
    Plot({"sharp plot", color="gray"
        },
        Table([f_rel,  G_R_reg_strong])
    ),

    Plot({"sharp plot", line_width="0.01cm", color="green"
        },
    Table([f_rel, max.(-10, G_R_nothing)])
    ),
)
pgfsave("../../paper/figures/test_chart_relative_energy_regain.pdf", plt1)
plt1
# Out:
# PGFPlotsX.Axis(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("xlabel" => "\$f/f_{\\textrm{max}} \$", "ylabel" => "relative energy regain \$G_{\\textrm{R}}\$", "xmin" => 0, "xmax" => 2.5, "ymin" => -1, "ymax" => 1.2, "legend_pos" => "north east", "legend_entries" => PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("measured" => nothing, "GR \$\\lambda=0.08\$" => nothing, "GR \$\\lambda=0.5\$" => nothing, "no regularizer" => nothing), true)), true), Any[Plot(false, false, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("sharp plot" => nothing, "color" => "red"), true), Table(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}(), false), TableData([0.0 0.9999994718265814; 0.01 0.9998666930958039; … ; 3.53 -8.282984838362976; 3.5349999999999997 0.9832611684130325], nothing, Int64[], true)), Any[]), Plot(false, false, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("sharp plot" => nothing, "color" => "blue"), true), Table(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}(), false), TableData([0.0 0.9999827392969933; 0.01 0.9999612012840173; … ; 3.53 0.005399121008946096; 3.5349999999999997 0.018231516704221847], nothing, Int64[], true)), Any[]), Plot(false, false, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("sharp plot" => nothing, "color" => "gray"), true), Table(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}(), false), TableData([0.0 0.9998031618358455; 0.01 0.9995815918095732; … ; 3.53 0.00369608751104699; 3.5349999999999997 0.01726457201460201], nothing, Int64[], true)), Any[]), Plot(false, false, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("sharp plot" => nothing, "line_width" => "0.01cm", "color" => "green"), true), Table(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}(), false), TableData([0.0 0.9999991034708278; 0.01 0.9999500248319572; … ; 3.53 -0.004878035557035788; 3.5349999999999997 0.055790420760901356], nothing, Int64[], true)), Any[])])

# %%
plt2 = @pgf PGFPlotsX.Axis(
    {xlabel="iterations", ylabel="normalized cross correlation (NCC)",
        xmin=0, xmax=50, ymin=0.85, ymax=0.94, 
        legend_pos="south east", legend_entries={"regularizer \$\\lambda=0.08\$",  "regularizer \$\\lambda=0.5\$", "no regularizer"}},
    
    Plot({"sharp plot", color="blue"
        },
        Table([1:length(ncc_log_reg), ncc_log_reg])
    ),
    Plot({"sharp plot", color="gray"
        },
        Table([1:length(ncc_log_reg_strong), ncc_log_reg_strong])
    ),
    
    Plot({"sharp plot", color="green"
        },
        Table([1:length(ncc_log_no_reg), ncc_log_no_reg])
    ),

)
pgfsave("../../paper/figures/test_chart_ncc.pdf", plt2)
plt2
# Out:
# PGFPlotsX.Axis(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("xlabel" => "iterations", "ylabel" => "normalized cross correlation (NCC)", "xmin" => 0, "xmax" => 50, "ymin" => 0.85, "ymax" => 0.94, "legend_pos" => "south east", "legend_entries" => PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("regularizer \$\\lambda=0.08\$" => nothing, "regularizer \$\\lambda=0.5\$" => nothing, "no regularizer" => nothing), true)), true), Any[Plot(false, false, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("sharp plot" => nothing, "color" => "blue"), true), Table(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}(), false), TableData(Float32[1.0 -2.6415057f-6; 2.0 0.8423807; … ; 21.0 0.92408603; 22.0 0.92408603], nothing, Int64[], true)), Any[]), Plot(false, false, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("sharp plot" => nothing, "color" => "gray"), true), Table(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}(), false), TableData(Float32[1.0 -2.6415057f-6; 2.0 0.84254724; … ; 36.0 0.90424365; 37.0 0.90424365], nothing, Int64[], true)), Any[]), Plot(false, false, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}("sharp plot" => nothing, "color" => "green"), true), Table(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any, Any}(), false), TableData(Float32[1.0 -2.6415057f-6; 2.0 0.8423413; … ; 50.0 0.77806306; 51.0 0.77852565], nothing, Int64[], true)), Any[])])
